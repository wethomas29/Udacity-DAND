# %% [markdown]
# # Project 3: OpenStreetMap Data Wrangling with SQL

# %%
# Importing libraries
import xml.etree.cElementTree as ET
from pprint import pprint
import re
from collections import defaultdict
import csv
import codecs
import cerberus

# %%
# %load schema.py
# Note: The schema is stored in a .py file in order to take advantage of the
# int() and float() type coercion functions. Otherwise it could easily stored as
# as JSON or another serialized format.

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %% [markdown]
# # Extract Sample File

# %%
# Creating sample file as original OSM is 1.28 GB unzipped.
# Parameter: take every k-th top level element
#Sample size is 128.9 MB

OSM_FILE = "new-orleans_louisiana.osm"
SAMPLE_FILE = "new-orleans_louisiana_sample.osm"

k = 10

def get_element(osm_file, tags=('node', 'way', 'relation')):
    '''Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    '''
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write(b'<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write(b'<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write(b'</osm>')

# %% [markdown]
# # 1 - Load dataset and search for incorrect street abbreviations.

# %%
# Load the sample OSM file as provided in GitHub repository
OSMFILE = "new-orleans_louisiana_sample.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road"]

# %% [markdown]
# There were a number of street names that were just inconsistent and had to be changed.

# %%
# Create a group of auditing functions for street suffix
def audit_street_type(street_types, street_name):
    """ Checks if street name contains incorrect abbreviations, if so, adds it to the dictionary. """
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    """ Returns a Boolean value """
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    """ Iterates through document tags, and returns dictionary
        of incorrect abbreviations (keys) and street names (value) that contain these abbreviations.
    """
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# Run audit and print results
st_types = audit(OSMFILE)
pprint(dict(st_types))
# Out:
# {'1': set(['Highway 1']),
#  '10': set(['Interstate 10']),
#  '132': set(['Road 132']),
#  '134': set(['Road 134']),
#  '141': set(['Road 141']),
#  '18': set(['LA 18']),
#  '204': set(['Manhattan Boulevard Bldg F #204']),
#  '232': set(['Rd. 232', 'Road 232']),
#  '234': set(['Road 234']),
#  '254': set(['Road 254']),
#  '259': set(['Road 259']),
#  '266': set(['Road 266']),
#  '302': set(['Road 302']),
#  '307': set(['Road 307']),
#  '309': set(['Road 309']),
#  '310': set(['Road 310']),
#  '326': set(['Road 326']),
#  '330': set(['Road 330']),
#  '346': set(['Road 346']),
#  '357': set(['Road 357']),
#  '361': set(['Road 361']),
#  '372': set(['Road 372']),
#  '373': set(['Road 373']),
#  '378': set(['Road 378']),
#  '380': set(['Road 380']),
#  '4058': set(['Northshore Blvd #4058']),
#  '43': set(['Highway 43']),
#  '433': set(['Road 433']),
#  '49': set(['Highway 49', 'Old Highway 49']),
#  '503': set(['Road 503']),
#  '528': set(['Road 528']),
#  '53': set(['Highway 53']),
#  '534': set(['Road 534']),
#  '541': set(['Road 541']),
#  '546': set(['Road 546']),
#  '548': set(['Road 548']),
#  '550': set(['Road 550']),
#  '556': set(['Road 556']),
#  '558': set(['Road 558']),
#  '603': set(['Highway 603']),
#  '604': set(['Highway 604']),
#  '90': set(['Highway 90']),
#  'A': set(['Avenue A', 'LA-22 #A']),
#  'Alley': set(['Pirates Alley']),
#  'Amar': set(['Amar']),
#  'Analii': set(['Analii']),
#  'Andree': set(['Rue Andree']),
#  'Anela': set(['Anela']),
#  'Arnoult': set(['N Arnoult']),
#  'Ave': set(['Franklin Ave', 'N Carrollton Ave', 'Orleans Ave']),
#  'B': set(['Avenue B']),
#  'Bayou': set(['Grand Plains Bayou',
#                "Joe'S Bayou",
#                'Rotten Bayou',
#                'Turkey Bayou']),
#  'Bend': set(['Giveans Bend']),
#  'Beverly': set(['Beverly']),
#  'Bienville': set(['Bienville']),
#  'Bird': set(['Blue Bird']),
#  'Blaize': set(['Blaize']),
#  'Bluff': set(['Jordan Bluff']),
#  'Blvd': set(['N Causeway Blvd']),
#  'Boardman': set(['Boardman']),
#  'Bookter': set(['Bookter']),
#  'Branch': set(['Whispering Branch']),
#  'Breland': set(['Breland']),
#  'Chapman': set(['Chapman']),
#  'Chickasaw': set(['Chickasaw']),
#  'Circle': set(['Ahekolo Circle',
#                 'Bayou Circle',
#                 'Bell Circle',
#                 'Bent Tree Circle',
#                 'Betts Circle',
#                 'Boggs Circle',
#                 'Bonita Circle',
#                 'Brandt Circle',
#                 'Campbell Circle',
#                 'Champion Circle',
#                 'Citadel Circle',
#                 'Clearwater Circle',
#                 'Dart Circle',
#                 'Debore Circle',
#                 'Dogwood Circle',
#                 'East Easterlyn Circle',
#                 'East Rockton Circle',
#                 'East Wheaton Circle',
#                 'Easterlyn Circle',
#                 'Five Oaks Circle',
#                 'Gandy Circle',
#                 'Hanalei Circle',
#                 'Harbor Circle',
#                 'Jacksonville Circle',
#                 'Jo Ellen Circle',
#                 'King Circle',
#                 'Kyle Circle',
#                 'Lassere Circle',
#                 'Lynn Circle',
#                 'Lynwood Circle',
#                 'Maplewood Circle',
#                 'Marcus Christian Circle',
#                 'Maui Circle',
#                 'Mystic Circle',
#                 'North Easterlyn Circle',
#                 'North Necaise Circle',
#                 'North St Andrews Circle',
#                 'Northwood Circle',
#                 'Pecan Circle',
#                 'Pinecrest Circle',
#                 'Plauche Circle',
#                 'Pompano Circle',
#                 'Roddy Circle',
#                 'Royal Circle',
#                 'Ryan Circle',
#                 'South Easterlyn Circle',
#                 'South St Andrews Circle',
#                 'Stablewood Circle',
#                 'Summerhaven Circle',
#                 'Tahiti Circle',
#                 'Tyler Circle',
#                 'West Rockton Circle',
#                 'West St Andrews Circle',
#                 'West Wheaton Circle',
#                 'Winners Circle']),
#  'Club': set(['Sportsmans Lake Club']),
#  'Colette': set(['Rue Colette']),
#  'Combel': set(['Combel']),
#  'Cove': set(['Banbury Cove',
#               'Beth Cove',
#               'Brandi Cove',
#               'Brianna Cove',
#               'Cardinal Cove',
#               'Creekside Cove',
#               'Dundee Cove',
#               'Eagle Cove',
#               'Ironwood Cove',
#               'Kirsten Cove',
#               'Lancaster Cove',
#               'Leeward Cove',
#               'Magnolia Cove',
#               'Maple Cove',
#               'North Cove',
#               "Ol' Mans Cove",
#               'Palmetto Cove',
#               'Pecanwood Cove',
#               'Pelican Cove',
#               'Pine Cove',
#               'Ridgewood Cove',
#               'Spanish Cove',
#               'Tarpon Cove',
#               'Timberlane Cove',
#               'Wheaton Cove']),
#  'Creek': set(['Quail Creek']),
#  'Cut-Off': set(['Kiln Waveland Cut-Off', 'Kiln-Waveland Cut-Off']),
#  'D': set(['Avenue D', 'Road D']),
#  'Davis': set(['Jeff Davis']),
#  'Delphine': set(['Rue Delphine']),
#  'Demontluzin': set(['Demontluzin']),
#  'Denise': set(['Rue Denise']),
#  'Domaines': set(['Rue Domaines']),
#  'Dr': set(['Keeneland Dr']),
#  'Drinkwater': set(['Drinkwater']),
#  'Duthu': set(['Duthu']),
#  'E': set(['Avenue E']),
#  'East': set(['Bayou View East', 'Diamondhead Drive East', 'Road East']),
#  'Elbow': set(['Devils Elbow']),
#  'Espana': set(['Espana']),
#  'Esplanade': set(['Esplanade']),
#  'Fayard': set(['Fayard']),
#  'Felicity': set(['Felicity']),
#  'Fontaine': set(['Rue Parc Fontaine']),
#  'Gardens': set(['Woodland Gardens']),
#  'Gulfside': set(['Gulfside']),
#  'H': set(['Avenue H']),
#  'Hawthorn': set(['Hawthorn']),
#  'Herlihy': set(['Herlihy']),
#  'Hibiscus': set(['Hibiscus']),
#  'Hightower': set(['Off Hightower']),
#  'Highway': set(['Airline Highway',
#                  'Behrman Highway',
#                  'Belle Chasse Highway',
#                  'Chef Menteur Highway',
#                  'Jefferson Highway',
#                  'No Hammond Highway',
#                  'Old Covington Highway',
#                  'Woodland Highway']),
#  'Hill': set(['Chapel Hill', 'Honeymoon Hill', 'Pleasant Hill']),
#  'Hollow': set(['Possum Hollow']),
#  'Hudson': set(['Hudson']),
#  'Hwy': set(['Jefferson Hwy']),
#  'I-10': set(['Off I-10']),
#  'John': set(['Grand Route St John']),
#  'Kapalama': set(['Kapalama']),
#  'Keller': set(['Keller']),
#  'Kiowa': set(['Kiowa']),
#  'Knee': set(['Cypress Knee']),
#  'LOOP': set(['Fairfield LOOP']),
#  'Lakeshore': set(['Lakeshore']),
#  'Lamar': set(['East Lamar']),
#  'Lasalle': set(['Rue De Lasalle']),
#  'Longfellow': set(['Longfellow']),
#  'Loop': set(['Poinsetta Loop', 'Youngswood Loop']),
#  'Merritt': set(['Merritt']),
#  'Mignon': set(['Rue Mignon']),
#  'Moana': set(['Ala Moana']),
#  'N/A': set(['N/A']),
#  'Nadine': set(['Rue Nadine']),
#  'Necaise': set(['Necaise']),
#  'Nevada': set(['Nevada']),
#  'Nichole': set(['Rue Nichole']),
#  'North': set(['Daytona Drive North',
#                'Diamondhead Drive North',
#                'Forest Avenue North',
#                'Seal Avenue North']),
#  'Oak': set(['Live Oak', 'Royal Oak', 'West Royal Oak']),
#  'Oaks': set(['Bay Oaks']),
#  'PARK': set(['Westgrove PARK']),
#  'Park': set(['Espana Park', 'Pecan Park', 'Rosa Park']),
#  'Parkway': set(['Industrial Parkway',
#                  'Lake Oaks Parkway',
#                  'Lakeshore Parkway',
#                  'Louisiana Ave Parkway',
#                  'Nie Parkway',
#                  'North Jefferson Davis Parkway',
#                  'South Clearview Parkway',
#                  'South Jefferson Davis Parkway',
#                  'Westbend Parkway']),
#  'Pass': set(['Sundance Pass']),
#  'Pines': set(['Whispering Pines']),
#  'Plaza': set(['Trianon Plaza']),
#  'Point': set(['Biloxi Point', 'Cedarwood Point']),
#  'ROADWAY': set(['Canal ROADWAY']),
#  'Renee': set(['Rue Renee']),
#  'Ridge': set(['Pine Ridge']),
#  'River': set(['Old Lazy River']),
#  'Row': set(['Park Row']),
#  'Run': set(['Rabbit Run', 'Whitetail Run']),
#  'Ryan': set(['Ryan']),
#  'South': set(['Lakeview Court South']),
#  'St': set(['Royal St']),
#  'Sycamore': set(['Sycamore']),
#  'Tarrace': set(['Chantilly Tarrace']),
#  'Taylor': set(['General Taylor']),
#  'Terrace': set(['Chantilly Terrace', 'Terrace', 'Todd Terrace']),
#  'Terre': set(['Rue La Terre']),
#  'Thames': set(['Thames']),
#  'Toulme': set(['Union & Toulme']),
#  'Trace': set(['Azalea Trace', 'Camellia Trace']),
#  'Trail': set(['Benesheewah Trail',
#                'Dogwood Trail',
#                'Old Spanish Trail',
#                'Ponderosa Trail',
#                'Sweetwater Trail']),
#  'Trot': set(['Fox Trot']),
#  'Turn': set(["Teacher'S Turn"]),
#  'View': set(['Bayou View']),
#  'Villa': set(['Lanai Villa', 'Molokai Villa']),
#  'Wainwright': set(['Wainwright']),
#  'Walk': set(['Magic Walk', 'Perrault Walk', 'Sojourne Walk']),
#  'Walnut': set(['Birch And Walnut']),
#  'Watts': set(['Watts']),
#  'Way': set(['Alafia Way',
#              'Annson Way',
#              'Augusta Way',
#              'Avalon Way',
#              'Boulevard Way',
#              'Coelho Way',
#              'East Way',
#              'Fucich Way',
#              'Hilo Way',
#              'Kaleki Way',
#              'Kalipekona Way',
#              'Kipapa Way',
#              'Kolo Way',
#              'Laa La Way',
#              'Linohau Way',
#              'Live Oak Way',
#              'Luawai Way',
#              'Luwai Way',
#              'Manini Way',
#              'Moana Lua Way',
#              'Moanalua Way',
#              'New Basin Way',
#              'Op La Way',
#              'Opla Way',
#              'Patio Way',
#              'Pokai Way',
#              'Possum Way',
#              'Quail Way',
#              'Redbud Way',
#              'Ursula Spencer Way',
#              'Winding Way',
#              'Woodland Way']),
#  'West': set(['Bayou View West', 'Diamondhead Drive West']),
#  'Yazoo': set(['Yazoo'])}

# %%
# Function to correct street names using wrong suffix
def update_name(name, mapping):
    """ Substitutes incorrect abbreviation with correct one. """
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        
        temp= 0
        try:
            temp = int(street_type)
        except:
            pass
        
        if street_type not in expected and temp == 0:
            try:
                name = re.sub(street_type_re, mapping[street_type], name)
            except:
                pass
    return name

# %%
# Dictionary mapping incorrect abbreviations to correct one.
mapping = { "St": "Street",
            "St.": "Street",
            "ST": "Street",
            "st": "Street",
            "Rd.": "Road",
            "Rd": "Road",
            "RD": "Road",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Blvd": "Boulevard",
            "BLVD": "Boulevard",
            "Cir": "Circle",
            "Ct": "Court",
            "Dr": "Drive",
            "Trl": "Trail",
            "Ter": "Terrace",
            "Pl": "Place",
            "Pkwy": "Parkway",
            "Bnd": "Bend",
            "Mnr": "Manor",
            "Ln": "Lane",
            "street": "Street",
            "AVE": "Avenue",
            "Blvd.": "Boulevard",
            "Cirlce": "Circle",
            "DRIVE": "Drive",
            "Cv": "Cove",
            "Dr.": "Drive",
            "Druve": "Drive",
            "Holw": "Hollow",
            "Hwy": "Highway",
            "HWY": "Highway",
            "Pt": "Point",
            "Trce": "Trace",
            "ave": "Avenue",
            "Cres": "Crescent"
            }

# %%
# Apply corrections where incorrect detected v. mapping.
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# Rue La Terre => Rue La Terre
# Pine Ridge => Pine Ridge
# Westgrove PARK => Westgrove PARK
# Drinkwater => Drinkwater
# Road 132 => Road 132
# Honeymoon Hill => Honeymoon Hill
# Pleasant Hill => Pleasant Hill
# Chapel Hill => Chapel Hill
# Whispering Branch => Whispering Branch
# Road 134 => Road 134
# Bay Oaks => Bay Oaks
# Espana => Espana
# Blue Bird => Blue Bird
# Lakeshore => Lakeshore
# Off Hightower => Off Hightower
# Rue Nichole => Rue Nichole
# North Cove => North Cove
# Brandi Cove => Brandi Cove
# Eagle Cove => Eagle Cove
# Cardinal Cove => Cardinal Cove
# Pecanwood Cove => Pecanwood Cove
# Tarpon Cove => Tarpon Cove
# Brianna Cove => Brianna Cove
# Ol' Mans Cove => Ol' Mans Cove
# Pelican Cove => Pelican Cove
# Ironwood Cove => Ironwood Cove
# Banbury Cove => Banbury Cove
# Dundee Cove => Dundee Cove
# Magnolia Cove => Magnolia Cove
# Palmetto Cove => Palmetto Cove
# Kirsten Cove => Kirsten Cove
# Beth Cove => Beth Cove
# Pine Cove => Pine Cove
# Wheaton Cove => Wheaton Cove
# Creekside Cove => Creekside Cove
# Maple Cove => Maple Cove
# Leeward Cove => Leeward Cove
# Timberlane Cove => Timberlane Cove
# Spanish Cove => Spanish Cove
# Ridgewood Cove => Ridgewood Cove
# Lancaster Cove => Lancaster Cove
# Road 346 => Road 346
# Road 541 => Road 541
# Road 546 => Road 546
# Amar => Amar
# Road 548 => Road 548
# Kapalama => Kapalama
# Road D => Road D
# Avenue D => Avenue D
# Avenue H => Avenue H
# Off I-10 => Off I-10
# Teacher'S Turn => Teacher'S Turn
# Kiowa => Kiowa
# Road 266 => Road 266
# Devils Elbow => Devils Elbow
# Old Lazy River => Old Lazy River
# Quail Creek => Quail Creek
# Molokai Villa => Molokai Villa
# Lanai Villa => Lanai Villa
# Blaize => Blaize
# Highway 53 => Highway 53
# Rue Colette => Rue Colette
# Rue Denise => Rue Denise
# Road 378 => Road 378
# Road 534 => Road 534
# Bookter => Bookter
# Road 373 => Road 373
# Road 372 => Road 372
# Fairfield LOOP => Fairfield LOOP
# Fox Trot => Fox Trot
# Rue Renee => Rue Renee
# Herlihy => Herlihy
# Diamondhead Drive West => Diamondhead Drive West
# Bayou View West => Bayou View West
# Road 310 => Road 310
# Birch And Walnut => Birch And Walnut
# Pirates Alley => Pirates Alley
# Dogwood Circle => Dogwood Circle
# Pecan Circle => Pecan Circle
# Tyler Circle => Tyler Circle
# Debore Circle => Debore Circle
# Bent Tree Circle => Bent Tree Circle
# Citadel Circle => Citadel Circle
# Dart Circle => Dart Circle
# West St Andrews Circle => West St Andrews Circle
# North Necaise Circle => North Necaise Circle
# Clearwater Circle => Clearwater Circle
# Ahekolo Circle => Ahekolo Circle
# Jacksonville Circle => Jacksonville Circle
# Ryan Circle => Ryan Circle
# Lynn Circle => Lynn Circle
# East Wheaton Circle => East Wheaton Circle
# Bonita Circle => Bonita Circle
# Betts Circle => Betts Circle
# Maui Circle => Maui Circle
# Pompano Circle => Pompano Circle
# West Wheaton Circle => West Wheaton Circle
# East Easterlyn Circle => East Easterlyn Circle
# Maplewood Circle => Maplewood Circle
# East Rockton Circle => East Rockton Circle
# Gandy Circle => Gandy Circle
# Royal Circle => Royal Circle
# Northwood Circle => Northwood Circle
# Hanalei Circle => Hanalei Circle
# North St Andrews Circle => North St Andrews Circle
# King Circle => King Circle
# Five Oaks Circle => Five Oaks Circle
# Lynwood Circle => Lynwood Circle
# Plauche Circle => Plauche Circle
# Champion Circle => Champion Circle
# Easterlyn Circle => Easterlyn Circle
# West Rockton Circle => West Rockton Circle
# South Easterlyn Circle => South Easterlyn Circle
# Summerhaven Circle => Summerhaven Circle
# Stablewood Circle => Stablewood Circle
# Tahiti Circle => Tahiti Circle
# Bell Circle => Bell Circle
# Lassere Circle => Lassere Circle
# Campbell Circle => Campbell Circle
# Bayou Circle => Bayou Circle
# Winners Circle => Winners Circle
# Marcus Christian Circle => Marcus Christian Circle
# North Easterlyn Circle => North Easterlyn Circle
# Brandt Circle => Brandt Circle
# South St Andrews Circle => South St Andrews Circle
# Pinecrest Circle => Pinecrest Circle
# Roddy Circle => Roddy Circle
# Jo Ellen Circle => Jo Ellen Circle
# Mystic Circle => Mystic Circle
# Boggs Circle => Boggs Circle
# Harbor Circle => Harbor Circle
# Kyle Circle => Kyle Circle
# Grand Route St John => Grand Route St John
# Possum Hollow => Possum Hollow
# East Lamar => East Lamar
# Hawthorn => Hawthorn
# Rabbit Run => Rabbit Run
# Whitetail Run => Whitetail Run
# Rue Andree => Rue Andree
# Ala Moana => Ala Moana
# Espana Park => Espana Park
# Rosa Park => Rosa Park
# Pecan Park => Pecan Park
# Fayard => Fayard
# Anela => Anela
# Road 528 => Road 528
# Road 361 => Road 361
# Road 309 => Road 309
# Watts => Watts
# Road 302 => Road 302
# Trianon Plaza => Trianon Plaza
# Road 307 => Road 307
# Road 380 => Road 380
# Jeff Davis => Jeff Davis
# Rue De Lasalle => Rue De Lasalle
# Youngswood Loop => Youngswood Loop
# Poinsetta Loop => Poinsetta Loop
# General Taylor => General Taylor
# Biloxi Point => Biloxi Point
# Cedarwood Point => Cedarwood Point
# Whispering Pines => Whispering Pines
# Northshore Blvd #4058 => Northshore Blvd #4058
# Sundance Pass => Sundance Pass
# Road 433 => Road 433
# Park Row => Park Row
# Hibiscus => Hibiscus
# Giveans Bend => Giveans Bend
# Road 330 => Road 330
# Joe'S Bayou => Joe'S Bayou
# Rotten Bayou => Rotten Bayou
# Turkey Bayou => Turkey Bayou
# Grand Plains Bayou => Grand Plains Bayou
# Road 259 => Road 259
# Kalipekona Way => Kalipekona Way
# New Basin Way => New Basin Way
# Possum Way => Possum Way
# Kipapa Way => Kipapa Way
# Quail Way => Quail Way
# Op La Way => Op La Way
# Linohau Way => Linohau Way
# Manini Way => Manini Way
# Annson Way => Annson Way
# Augusta Way => Augusta Way
# Avalon Way => Avalon Way
# Hilo Way => Hilo Way
# Moanalua Way => Moanalua Way
# East Way => East Way
# Patio Way => Patio Way
# Ursula Spencer Way => Ursula Spencer Way
# Luwai Way => Luwai Way
# Moana Lua Way => Moana Lua Way
# Winding Way => Winding Way
# Boulevard Way => Boulevard Way
# Laa La Way => Laa La Way
# Opla Way => Opla Way
# Redbud Way => Redbud Way
# Kaleki Way => Kaleki Way
# Live Oak Way => Live Oak Way
# Pokai Way => Pokai Way
# Fucich Way => Fucich Way
# Luawai Way => Luawai Way
# Alafia Way => Alafia Way
# Coelho Way => Coelho Way
# Kolo Way => Kolo Way
# Woodland Way => Woodland Way
# Wainwright => Wainwright
# Kiln-Waveland Cut-Off => Kiln-Waveland Cut-Off
# Kiln Waveland Cut-Off => Kiln Waveland Cut-Off
# Road 254 => Road 254
# Chantilly Tarrace => Chantilly Tarrace
# Combel => Combel
# Necaise => Necaise
# Diamondhead Drive North => Diamondhead Drive North
# Forest Avenue North => Forest Avenue North
# Seal Avenue North => Seal Avenue North
# Daytona Drive North => Daytona Drive North
# Demontluzin => Demontluzin
# Dogwood Trail => Dogwood Trail
# Benesheewah Trail => Benesheewah Trail
# Ponderosa Trail => Ponderosa Trail
# Sweetwater Trail => Sweetwater Trail
# Old Spanish Trail => Old Spanish Trail
# Rue Delphine => Rue Delphine
# Rue Nadine => Rue Nadine
# Cypress Knee => Cypress Knee
# Union & Toulme => Union & Toulme
# Road 503 => Road 503
# Avenue B => Avenue B
# Boardman => Boardman
# N/A => N/A
# Royal St => Royal Street
# Thames => Thames
# Beverly => Beverly
# Highway 90 => Highway 90
# South Jefferson Davis Parkway => South Jefferson Davis Parkway
# South Clearview Parkway => South Clearview Parkway
# Lake Oaks Parkway => Lake Oaks Parkway
# Industrial Parkway => Industrial Parkway
# Louisiana Ave Parkway => Louisiana Ave Parkway
# Lakeshore Parkway => Lakeshore Parkway
# North Jefferson Davis Parkway => North Jefferson Davis Parkway
# Westbend Parkway => Westbend Parkway
# Nie Parkway => Nie Parkway
# Road 556 => Road 556
# Longfellow => Longfellow
# Canal ROADWAY => Canal ROADWAY
# Interstate 10 => Interstate 10
# LA 18 => LA 18
# Esplanade => Esplanade
# Perrault Walk => Perrault Walk
# Sojourne Walk => Sojourne Walk
# Magic Walk => Magic Walk
# Bienville => Bienville
# Rue Mignon => Rue Mignon
# Analii => Analii
# N Carrollton Ave => N Carrollton Avenue
# Orleans Ave => Orleans Avenue
# Franklin Ave => Franklin Avenue
# Nevada => Nevada
# Highway 604 => Highway 604
# Yazoo => Yazoo
# Road 558 => Road 558
# Highway 603 => Highway 603
# Hudson => Hudson
# West Royal Oak => West Royal Oak
# Royal Oak => Royal Oak
# Live Oak => Live Oak
# Road 550 => Road 550
# Road 234 => Road 234
# Chef Menteur Highway => Chef Menteur Highway
# Woodland Highway => Woodland Highway
# Belle Chasse Highway => Belle Chasse Highway
# Jefferson Highway => Jefferson Highway
# Airline Highway => Airline Highway
# Behrman Highway => Behrman Highway
# Old Covington Highway => Old Covington Highway
# No Hammond Highway => No Hammond Highway
# N Arnoult => N Arnoult
# Road East => Road East
# Bayou View East => Bayou View East
# Diamondhead Drive East => Diamondhead Drive East
# Rue Parc Fontaine => Rue Parc Fontaine
# Old Highway 49 => Old Highway 49
# Highway 49 => Highway 49
# Sportsmans Lake Club => Sportsmans Lake Club
# Highway 43 => Highway 43
# Highway 1 => Highway 1
# Felicity => Felicity
# Road 326 => Road 326
# Rd. 232 => Rd. 232
# Road 232 => Road 232
# Jordan Bluff => Jordan Bluff
# Jefferson Hwy => Jefferson Highway
# Keeneland Dr => Keeneland Drive
# Breland => Breland
# Avenue A => Avenue A
# LA-22 #A => LA-22 #A
# Avenue E => Avenue E
# Manhattan Boulevard Bldg F #204 => Manhattan Boulevard Bldg F #204
# Road 141 => Road 141
# Sycamore => Sycamore
# Chapman => Chapman
# Ryan => Ryan
# Merritt => Merritt
# Woodland Gardens => Woodland Gardens
# Lakeview Court South => Lakeview Court South
# Bayou View => Bayou View
# Rue Domaines => Rue Domaines
# Camellia Trace => Camellia Trace
# Azalea Trace => Azalea Trace
# Chickasaw => Chickasaw
# Duthu => Duthu
# Road 357 => Road 357
# Todd Terrace => Todd Terrace
# Terrace => Terrace
# Chantilly Terrace => Chantilly Terrace
# Keller => Keller
# N Causeway Blvd => N Causeway Boulevard
# Gulfside => Gulfside

# %% [markdown]
# # Zip Code

# %%
# # Create a group of auditing functions for postal codes

def audit_postcode(post_code, digits):
    """ Checks if postal code is incompatible and adds it to the list if so. """
    if len(digits) != 5 or (digits[0:2] != '01' and digits[0:2] != '02'):
        post_code.append(digits)
        
def is_postalcode(elem):
    """ Returns a Boolean value."""
    return (elem.attrib['k'] == "addr:postcode")


def audit(osmfile):
    """ Iterates and returns list of inconsistent postal codes found in the document. """
    osm_file = open(osmfile, "r")
    post_code = []
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postalcode(tag):
                    audit_postcode(post_code, tag.attrib['v'])
    osm_file.close()
    return post_code

# %%
# Run audit and print results
postal_codes = audit(OSMFILE)
print postal_codes
# Out:
# ['70118', '70122', '70115', '70002', '70119', '70112', '70130', '70002', '70118', '70118', '70115', '70130', '70130', '70403', '70130', '70115', '70115', '70130', '70012', '70072', '70130', '70433', '70447', '70118', '70115', '70115', '70118', '70460', '70002', '70462', '70058', '70130', '70112', '70130', '70130', '70130', '70117', '70032', '70446', '39571', '39503', '39560', '39571', '39571', '39571', '39571', '39571', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39503', '39503', '39503', '39503', '39503', '39503', '39574', '39503', '39574', '39503', '39503', '39503', '39503', '39503', '39503', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39571', '39503', '39571', '39571', '39571', '39503', '39571', '39503', '39503', '39571', '39571', '39571', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39501', '39501', '39501', '39501', '39501', '39501', '39560', '39560', '39560', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39501', '39560', '39560', '39560', '39501', '39503', '39560', '39560', '39501', '39501', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39503', '39 ...

# %%
# Apply corrections where incorrect detected (No problems with Zip Code)
#for code in postal_codes:
#    better_code = update_zip(code)
#    print code, "=>", better_code

# %% [markdown]
# #  3. Convert XML to CSV format

# %%
NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

# %%
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %%
# Regular expression compiler patterns.
LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema

# %%
# Check if input element is a "node" or a "way" then clean, shape and parse to corresponding dictionary.

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
    
    if element.tag == 'node':
        for field in node_attr_fields:
            node_attribs[field] = element.attrib[field]
    
    if element.tag == 'way':
        for field in way_attr_fields:
            way_attribs[field] = element.attrib[field]
        
        position = 0
        temp = {}
        for tag in element.iter("nd"):
            temp['id'] = element.attrib["id"]
            temp['node_id'] = tag.attrib["ref"]
            temp['position'] = position
            position += 1
            way_nodes.append(temp.copy())

    temp = {}
    for tag in element.iter("tag"):
        temp['id'] = element.attrib["id"]
        if ":" in tag.attrib["k"]:
            newKey = re.split(":",tag.attrib["k"],1)
            temp['key'] = newKey[1]
            elif temp['key'] == 'street':
                temp['value'] = update_name(tag.attrib["v"],mapping)
            else:
                temp['value'] = tag.attrib["v"]
            temp["type"] = newKey[0]
        else:
            temp['key'] = tag.attrib["k"]
            if temp['key'] == 'postcode':
                temp['value'] = update_zip(tag.attrib["v"])
            elif temp['key'] == 'street':
                temp['value'] = update_name(tag.attrib["v"],mapping)
            else:
                temp['value'] = tag.attrib["v"]
            temp["type"] = default_tag_type
        tags.append(temp.copy())  
        
    
    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}
# Out:
#   File "<ipython-input-19-aecafea7d6da>", line 35
#     elif temp['key'] == 'street':
#        ^
# SyntaxError: invalid syntax

# %%
# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )

class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %%
# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %%
process_map(OSMFILE, validate=False)

# %%
import sqlite3
db = sqlite3.connect("Nola.db")
c = db.cursor()

# %%
c.execute('''
CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT
);
''')

c.execute('''
CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id)
);
''')

c.execute('''
CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT
);
''')

c.execute('''
CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id)
);
''')

c.execute('''
CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id)
);
''')

db.commit()

# %%
# Read in the csv file as a dictionary, format the data as a list of tuples:
with open('nodes.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['lat'], i['lon'], i['user'].decode("utf-8"), i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]
    
# insert the formatted data
c.executemany("INSERT INTO nodes(id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?, ?, ?);", to_db)
# commit the changes
db.commit()

# %%
with open('nodes_tags.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['key'], i['value'].decode("utf-8"), i['type']) for i in dr]
    
# insert the formatted data
c.executemany("INSERT INTO nodes_tags(id, key, value,type) VALUES (?, ?, ?, ?);", to_db)
# commit the changes
db.commit()

# %%
with open('ways.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['user'].decode("utf-8"), i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]
    
# insert the formatted data
c.executemany("INSERT INTO ways(id, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?);", to_db)
# commit the changes
db.commit()

# %%
with open('ways_nodes.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['node_id'], i['position']) for i in dr]
    
# insert the formatted data
c.executemany("INSERT INTO ways_nodes(id, node_id, position) VALUES (?, ?, ?);", to_db)
# commit the changes
db.commit()

# %%
with open('ways_tags.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['key'], i['value'].decode("utf-8"), i['type']) for i in dr]
    
# insert the formatted data
c.executemany("INSERT INTO ways_tags(id, key, value, type) VALUES (?, ?, ?, ?);", to_db)
# commit the changes
db.commit()

# %% [markdown]
# # Overview of Data

# %% [markdown]
# <b>File sizes</b>
# <br>new-orleans_louisiana.osm .............. 424 MB</br>
# <br>new-orleans_louisiana_sample.osm .. 129.6 MB</br>
# <br>Nola.db ................................... 66.9 MB</br>
# <br>nodes.csv ............................... 52.9 MB</br>
# <br>nodes_tags.csv .......................... 7 MB</br>
# <br>ways.csv ................................. 2.3 MB</br>
# <br>ways_nodes.csv ......................... 17 MB</br>
# <br>ways_tags.csv .......................... 4.9 MB</br>

# %%
import sqlite3
db = sqlite3.connect("Nola.db")
c = db.cursor()

# %% [markdown]
# # Number of Ways

# %%
query = "SELECT count(*) FROM ways;"
c.execute(query)
c.fetchall()[0][0]

# %% [markdown]
# # Number of Common Way Tags (Top 5)

# %%
query = "SELECT key, count(*) FROM ways_tags GROUP BY 1 ORDER BY count(*) DESC LIMIT 5;"
c.execute(query)
c.fetchall()

# %% [markdown]
# # Number of Nodes

# %%
query = "SELECT count(*) FROM nodes;"
c.execute(query)
c.fetchall()[0][0]

# %% [markdown]
# # Number of Common Node Tags (Top 5)

# %%
query = "SELECT key,count(*) FROM nodes_tags GROUP BY 1 ORDER BY count(*) DESC LIMIT 5;"
c.execute(query)
c.fetchall()

# %% [markdown]
# # Contributors

# %%
query = "SELECT temp.user, count(*) as posts FROM (SELECT user, uid FROM ways UNION ALL SELECT user, uid FROM nodes) as temp \
GROUP BY temp.user ORDER BY posts DESC LIMIT 10;"
c.execute(query)
c.fetchall()

# %% [markdown]
# # Top Users

# %%
query = "SELECT count(DISTINCT(temp.uid)) FROM (SELECT user, uid FROM ways UNION ALL SELECT user, uid FROM nodes) as temp;"
c.execute(query)
c.fetchall()[0][0]

# %% [markdown]
# # Top 10 Amenities

# %%
query = "SELECT temp.value, count(*) as num \
FROM (SELECT key,value FROM ways_tags UNION ALL SELECT key,value FROM nodes_tags) as temp \
WHERE temp.key='amenity' GROUP BY temp.value ORDER BY num DESC LIMIT 10;"
c.execute(query)
c.fetchall()

# %% [markdown]
# # Cuisine

# %%
query = "SELECT temp.value, count(*) as num \
FROM (SELECT key,value FROM ways_tags UNION ALL SELECT key,value FROM nodes_tags) as temp \
WHERE temp.key='cuisine' GROUP BY temp.value ORDER BY num DESC LIMIT 10;"
c.execute(query)
c.fetchall()
